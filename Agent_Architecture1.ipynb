# %% [markdown]
# ### Cab-Driver Agent

# %%
# Importing libraries
import numpy as np
import random
import math
from collections import deque
import collections
import pickle
import time
from sklearn.externals import joblib 

# for building DQN model
from keras import layers
from keras import Sequential
from keras.layers import Dense, Activation, Flatten
from keras.optimizers import Adam

# for plotting graphs
import matplotlib.pyplot as plt

# Import the environment
from Env import CabDriver
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Defining Time Matrix

# %%
# Loading the time matrix provided
Time_matrix = np.load("TM.npy")

# %% [markdown]
# #### Tracking the state-action pairs for checking convergence

# %%
Time_matrix[0][1]
# Out:
# array([[2., 3., 3., 5., 7., 0., 6.],
#        [2., 3., 3., 5., 7., 0., 6.],
#        [2., 3., 3., 5., 7., 0., 6.],
#        [2., 3., 3., 5., 7., 0., 6.],
#        [2., 3., 3., 5., 7., 0., 6.],
#        [2., 3., 3., 5., 7., 0., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [9., 7., 9., 7., 8., 5., 6.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [4., 7., 6., 4., 3., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.],
#        [2., 3., 6., 2., 7., 4., 2.]])

# %%
#Defining a function to save the Q-dictionary as a pickle file
def save_obj(obj, name ):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### Agent Class
#
# If you are using this framework, you need to fill the following to complete the following code block:
# 1. State and Action Size
# 2. Hyperparameters
# 3. Create a neural-network model in function 'build_model()'
# 4. Define epsilon-greedy strategy in function 'get_action()'
# 5. Complete the function 'append_sample()'. This function appends the recent experience tuple <state, action, reward, new-state> to the memory
# 6. Complete the 'train_model()' function with following logic:
#    - If the memory size is greater than mini-batch size, you randomly sample experiences from memory as per the mini-batch size and do the following:
#       - Initialise your input and output batch for training the model
#       - Calculate the target Q value for each sample: reward + gamma*max(Q(s'a,))
#       - Get Q(s', a) values from the last trained model
#       - Update the input batch as your encoded state and output batch as your Q-values
#       - Then fit your DQN model using the updated input and output batch.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size, env):
        # Define size of state and action
        self.state_size = state_size
        self.action_size = action_size
        self.env = env

        # Write here: Specify you hyper parameters for the DQN
        self.discount_factor = 0.99
        self.learning_rate = 0.001       
        self.epsilon_max = 1.0
        self.epsilon = self.epsilon_max
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        
        self.batch_size = 32      

        # create replay memory using deque
        self.memory = deque(maxlen=2000)
        
        # Initialize the value of the states tracked
        self.states_tracked = []
        
        # We are going to track state [1,0,0] and action (0,1) at index 2 in the action space.
        self.track_state = np.array(self.env.state_encod_arch1([1,0,0])).reshape(1, 36)


        # create main model and target model
        self.model = self.build_model()

    # approximate Q function using Neural Network
    def build_model(self):
        model = Sequential()
        # Write your code here: Add layers to your neural nets       
        model.add(Dense(32, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(32, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.compile(loss='mse',optimizer=Adam(lr=self.learning_rate))
        model.summary
        return model



    def get_action(self, state):
    # Write your code here:
    # get action from model using epsilon-greedy policy
    # Decay in ε after we generate each sample from the environment       
        
        possible_actions_index, actions = env.requests(state)
        # choose random action if generated random number is less than ε.
        # Action is represented by index, 0-Number of actions, like (0,1,2,3) for 4 actions
        if np.random.rand() <= self.epsilon:
             return random.choice(possible_actions_index)
        # if generated random number is greater than ε, choose the action which has max Q-value
        else:
            state = np.array(self.env.state_encod_arch1(state)).reshape(1, 36)
            q_value = self.model.predict(state)
            q_vals_possible = [q_value[0][i] for i in possible_actions_index]

            return possible_actions_index[np.argmax(q_vals_possible)]


    def append_sample(self, state, action, reward, next_state, done):
    # Write your code here:
    # save sample <s,a,r,s'> to the replay memory
        # Adding sample to the memory. 
        self.memory.append((state, action, reward, next_state, done))
        
        # Decay in ε after we generate each sample from the environment
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
    
    # pick samples randomly from replay memory (with batch_size) and train the network
    def train_model(self):
        
        if len(self.memory) > self.batch_size:
            # Sample batch from the memory
            mini_batch = random.sample(self.memory, self.batch_size)
            update_output = np.zeros((self.batch_size, self.state_size))
            update_input = np.zeros((self.batch_size, self.state_size))
            
            action_list, reward_list, done_list = [], [], []
            
            # Set the values of input, action, reward, target and done using memory
            # Note the order of <s,a,r,s',done> 
            for i in range(self.batch_size):
                state, action, reward, next_state, done = mini_batch[i]
                update_input[i] = env.state_encod_arch1(state)
                action_list.append(action)
                reward_list.append(reward)
                update_output[i] = env.state_encod_arch1(next_state)
                done_list.append(done)
                
            # Write your code from here
            # 1. Predict the target from earlier model
            target = self.model.predict(update_input)

            # 2. Get the target for the Q-network
            target_val = self.model.predict(update_output)

            #3. Update your 'update_output' and 'update_input' batch
            for i in range(self.batch_size):
                # Q Learning: get maximum Q value at s' from target model
                if done_list[i]:
                    target[i][action_list[i]] = reward_list[i]
                else:
                    target[i][action_list[i]] = reward_list[i] + self.discount_factor * np.max(target_val[i])
                
                
            # 4. Fit your model and track the loss values
            self.model.fit(update_input, target, batch_size=self.batch_size,
                           epochs=1, verbose=0)

    def save_tracking_states(self):
        # Use the model to predict the q_value of the state we are tacking.
        q_value = self.model.predict(self.track_state)
        
        # Grab the q_value of the action index that we are tracking.
        self.states_tracked.append(q_value[0][1])
        
    def save(self, name):
        self.model.save(name)

# %%
Episodes = 10000
battery_life_time = 24*30

env = CabDriver()
action_space, state_space, state = env.reset()

# Set up state and action sizes.
agent = DQNAgent(action_size=len(action_space), state_size=36, env=env)

score_tracked = []
# to store rewards in each episode
rewards_per_episode, episodes = [], []

# %% [markdown]
# ### DQN block

# %%
start_time = time.time()

for episode in range(Episodes):
    
    # Write code here
   
    # Call the environment
    
    # Call all the initialised variables of the environment
    action_space, state_space, state = env.reset()
    terminal_state = False
    score = 0
    battery_consumed_time = 0
    #Call the DQN agent
    
    while (terminal_state == False):
        # Write your code here
        # 1. Pick epsilon-greedy action from possible actions for the current state
        action = agent.get_action(state)
        # 2. Evaluate your reward and next state
        reward, next_state, step_time = env.step(state, env.action_space[action], Time_matrix)
        # check the episode ended or not
        battery_consumed_time += step_time
        if (battery_consumed_time >= battery_life_time):
            terminal_state = True
        else:
            # 3. Append the experience to the memory
            agent.append_sample(state, action, reward, next_state, False)
            # 4. Train the model by calling function agent.train_model
            agent.train_model()
            # 5. Keep a track of rewards, Q-values, loss
            state = next_state
            score += reward
     
    # store total reward obtained in this episode
    rewards_per_episode.append(score)
    episodes.append(episode)
    
    # every 20 episodes:
    if ((episode + 1) % 20 == 0):
        print("episode:", episode, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon)
    
    if ((episode + 1) % 5 == 0):
        agent.save_tracking_states()
    
    # Total rewards per episode
    score_tracked.append(score)
    
print("Saving Model {}".format(episode))
agent.save(name="model_weights.pkl")

elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# episode: 19   score: 165.0   memory length: 2000   epsilon: 0.11157070860138803
# episode: 39   score: 548.0   memory length: 2000   epsilon: 0.014874537759091451
# episode: 59   score: 476.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 79   score: 268.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 99   score: 833.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 119   score: 749.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 139   score: 797.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 159   score: 1018.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 179   score: 1179.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 199   score: 978.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 219   score: 1054.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 239   score: 1274.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 259   score: 1096.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 279   score: 1191.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 299   score: 1298.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 319   score: 1154.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 339   score: 1352.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 359   score: 1735.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 379   score: 1432.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 399   score: 1608.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 419   score: 1486.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 439   score: 1551.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 459   score: 1488.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 479   score: 1979.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 499   score: 1337.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 519   score: 1445.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 539   score: 1199.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 559   score: 948.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 579   score: 1436.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 599   score: 1113.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 619   score: 1440.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 639   score: 1252.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 659   score: 848.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 679   score: 1513.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 699   score: 1420.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 719   score: 1328.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 739   score: 1228.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 759   score: 1356.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 779   score: 1452.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 799   score: 1213.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 819   score: 1592.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 839   score: 1213.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 859   score: 1279.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 879   score: 940.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 899   score: 1359.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 919   score: 1540.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 939   score: 1245.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 959   score: 1620.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 979   score: 1174.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 999   score: 1231.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1019   score: 1479.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1039   score: 1613.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1059   score: 1565.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1079   score: 1612.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1099   score: 1406.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1119   score: 1428.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1139   score: 1204.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1159   score: 1347.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1179   score: 1077.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1199   score: 1468.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1219   score: 1594.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1239   score: 1352.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1259   score: 1200.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1279   score: 1617.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1299   score: 1243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1319   score: 1329.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1339   score: 1721.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1359   score: 1272.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1379   score: 1387.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1399   score: 1288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1419   score: 1837.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1439   score: 1127.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1459   score: 1400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1479   score: 1123.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1499   score: 1011.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1519   score: 1261.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1539   score: 1397.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1559   score: 1328.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1579   score: 1513.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1599   score: 1271.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1619   score: 1039.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1639   score: 1812.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1659   score: 1336.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1679   score: 1032.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1699   score: 1494.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1719   score: 1325.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1739   score: 1497.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1759   score: 1393.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1779   score: 1735.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1799   score: 1403.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1819   score: 1397.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1839   score: 1243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1859   score: 1491.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1879   score: 1652.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1899   score: 1272.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1919   score: 1490.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1939   score: 1428.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1959   score: 1584.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1979   score: 1284.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 1999   score: 1204.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2019   score: 1252.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2039   score: 1418.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2059   score: 1261.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2079   score: 1675.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2099   score: 1336.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2119   score: 1505.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2139   score: 1091.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2159   score: 1274.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2179   score: 1594.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2199   score: 1376.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2219   score: 1221.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2239   score: 1474.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2259   score: 1611.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2279   score: 1300.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2299   score: 898.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2319   score: 1230.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2339   score: 1292.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2359   score: 1125.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2379   score: 1310.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2399   score: 1446.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2419   score: 1883.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2439   score: 1517.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2459   score: 1200.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2479   score: 1281.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2499   score: 1468.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2519   score: 1390.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2539   score: 1567.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2559   score: 1340.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2579   score: 1129.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2599   score: 1423.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2619   score: 1387.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2639   score: 1420.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2659   score: 999.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2679   score: 1681.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2699   score: 919.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2719   score: 1543.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2739   score: 1368.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2759   score: 1325.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2779   score: 1101.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2799   score: 1613.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2819   score: 1137.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2839   score: 1565.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2859   score: 1496.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2879   score: 1415.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2899   score: 967.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2919   score: 1580.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2939   score: 1243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2959   score: 1186.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2979   score: 1033.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 2999   score: 1200.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3019   score: 1357.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3039   score: 1418.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3059   score: 1451.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3079   score: 1553.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3099   score: 1234.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3119   score: 1387.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3139   score: 1219.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3159   score: 1328.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3179   score: 1224.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3199   score: 1373.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3219   score: 1598.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3239   score: 1301.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3259   score: 1339.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3279   score: 1282.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3299   score: 1440.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3319   score: 1142.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3339   score: 1510.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3359   score: 1066.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3379   score: 980.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3399   score: 1333.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3419   score: 1375.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3439   score: 1472.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3459   score: 1491.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3479   score: 1059.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3499   score: 1352.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3519   score: 1198.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3539   score: 1316.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3559   score: 1292.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3579   score: 1280.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3599   score: 1320.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3619   score: 981.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3639   score: 1474.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3659   score: 1528.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3679   score: 1220.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3699   score: 1281.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3719   score: 1229.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3739   score: 1332.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3759   score: 1046.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3779   score: 1523.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3799   score: 937.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3819   score: 1227.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3839   score: 1554.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3859   score: 763.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3879   score: 1409.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3899   score: 1026.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3919   score: 1397.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3939   score: 1263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3959   score: 1301.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3979   score: 1262.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 3999   score: 1068.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4019   score: 1267.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4039   score: 1203.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4059   score: 1058.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4079   score: 1096.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4099   score: 1625.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4119   score: 1086.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4139   score: 1482.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4159   score: 989.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4179   score: 1123.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4199   score: 1059.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4219   score: 1009.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4239   score: 1104.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4259   score: 1216.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4279   score: 1183.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4299   score: 1032.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4319   score: 1189.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4339   score: 1226.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4359   score: 1711.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4379   score: 1320.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4399   score: 1046.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4419   score: 1444.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4439   score: 1409.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4459   score: 1146.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4479   score: 1270.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4499   score: 1007.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4519   score: 953.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4539   score: 716.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4559   score: 1293.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4579   score: 1400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4599   score: 1407.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4619   score: 991.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4639   score: 1149.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4659   score: 1320.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4679   score: 1470.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4699   score: 1503.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4719   score: 1640.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4739   score: 1298.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4759   score: 1231.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4779   score: 1468.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4799   score: 1598.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4819   score: 1063.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4839   score: 1765.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4859   score: 1521.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4879   score: 1679.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4899   score: 1510.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4919   score: 1142.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4939   score: 1352.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4959   score: 1009.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4979   score: 1184.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 4999   score: 1605.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5019   score: 1227.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5039   score: 1304.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5059   score: 1099.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5079   score: 1555.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5099   score: 1099.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5119   score: 1073.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5139   score: 1258.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5159   score: 1112.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5179   score: 1660.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5199   score: 1490.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5219   score: 1679.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5239   score: 1010.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5259   score: 1549.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5279   score: 1285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5299   score: 1256.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5319   score: 1536.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5339   score: 1499.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5359   score: 1232.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5379   score: 1280.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5399   score: 1268.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5419   score: 1259.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5439   score: 1202.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5459   score: 1347.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5479   score: 1648.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5499   score: 1298.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5519   score: 1025.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5539   score: 1333.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5559   score: 1373.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5579   score: 1373.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5599   score: 1190.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5619   score: 1483.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5639   score: 1401.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5659   score: 1670.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5679   score: 1358.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5699   score: 1382.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5719   score: 1268.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5739   score: 1455.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5759   score: 1045.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5779   score: 1171.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5799   score: 1625.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5819   score: 1523.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5839   score: 1500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5859   score: 1365.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5879   score: 1450.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5899   score: 1243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5919   score: 1077.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5939   score: 1442.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5959   score: 1501.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5979   score: 1720.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 5999   score: 1446.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6019   score: 1347.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6039   score: 1462.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6059   score: 1469.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6079   score: 1274.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6099   score: 1211.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6119   score: 1451.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6139   score: 1452.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6159   score: 1451.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6179   score: 1471.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6199   score: 1263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6219   score: 1121.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6239   score: 1144.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6259   score: 1213.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6279   score: 1553.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6299   score: 1346.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6319   score: 1400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6339   score: 1061.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6359   score: 1675.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6379   score: 1068.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6399   score: 829.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6419   score: 934.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6439   score: 1793.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6459   score: 911.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6479   score: 1162.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6499   score: 1792.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6519   score: 1820.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6539   score: 1112.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6559   score: 1640.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6579   score: 1454.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6599   score: 1441.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6619   score: 1033.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6639   score: 867.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6659   score: 1571.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6679   score: 1373.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6699   score: 1384.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6719   score: 950.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6739   score: 1487.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6759   score: 1841.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6779   score: 1813.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6799   score: 1227.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6819   score: 1807.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6839   score: 1051.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6859   score: 1787.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6879   score: 1329.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6899   score: 953.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6919   score: 1393.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6939   score: 1465.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6959   score: 1237.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6979   score: 1263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 6999   score: 1042.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7019   score: 1514.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7039   score: 1869.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7059   score: 1486.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7079   score: 1418.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7099   score: 1063.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7119   score: 1651.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7139   score: 1038.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7159   score: 1493.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7179   score: 1385.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7199   score: 1387.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7219   score: 1585.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7239   score: 1549.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7259   score: 1285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7279   score: 1217.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7299   score: 1218.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7319   score: 1331.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7339   score: 1319.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7359   score: 1214.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7379   score: 1550.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7399   score: 1325.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7419   score: 1609.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7439   score: 1295.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7459   score: 1736.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7479   score: 1599.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7499   score: 1320.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7519   score: 1472.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7539   score: 1221.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7559   score: 1590.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7579   score: 1698.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7599   score: 1224.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7619   score: 1446.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7639   score: 1061.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7659   score: 1254.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7679   score: 1024.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7699   score: 1445.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7719   score: 1088.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7739   score: 1315.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7759   score: 1220.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7779   score: 1245.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7799   score: 1428.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7819   score: 1643.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7839   score: 1598.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7859   score: 1116.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7879   score: 1383.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7899   score: 1100.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7919   score: 1363.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7939   score: 1585.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7959   score: 1291.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7979   score: 1763.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 7999   score: 1648.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8019   score: 1235.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8039   score: 1288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8059   score: 1400.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8079   score: 1823.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8099   score: 1388.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8119   score: 1300.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8139   score: 1766.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8159   score: 1927.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8179   score: 1581.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8199   score: 1549.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8219   score: 1475.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8239   score: 1211.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8259   score: 946.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8279   score: 1445.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8299   score: 740.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8319   score: 1369.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8339   score: 1153.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8359   score: 1752.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8379   score: 1372.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8399   score: 1827.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8419   score: 1498.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8439   score: 1323.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8459   score: 1268.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8479   score: 1661.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8499   score: 1308.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8519   score: 1285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8539   score: 1751.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8559   score: 1060.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8579   score: 1443.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8599   score: 1391.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8619   score: 1288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8639   score: 1390.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8659   score: 1346.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8679   score: 1452.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8699   score: 1460.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8719   score: 962.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8739   score: 1392.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8759   score: 1346.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8779   score: 1277.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8799   score: 1523.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8819   score: 1697.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8839   score: 1668.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8859   score: 1208.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8879   score: 1550.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8899   score: 1468.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8919   score: 1285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8939   score: 1075.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8959   score: 1468.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8979   score: 1582.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 8999   score: 1374.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9019   score: 1470.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9039   score: 1437.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9059   score: 1450.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9079   score: 1303.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9099   score: 1301.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9119   score: 1510.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9139   score: 1338.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9159   score: 1649.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9179   score: 956.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9199   score: 982.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9219   score: 1546.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9239   score: 1090.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9259   score: 1238.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9279   score: 1284.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9299   score: 1690.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9319   score: 1270.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9339   score: 1243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9359   score: 1169.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9379   score: 1382.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9399   score: 1108.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9419   score: 1495.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9439   score: 1459.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9459   score: 1625.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9479   score: 1293.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9499   score: 907.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9519   score: 1616.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9539   score: 1630.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9559   score: 1180.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9579   score: 1327.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9599   score: 1690.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9619   score: 1329.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9639   score: 1432.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9659   score: 1279.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9679   score: 1486.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9699   score: 1700.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9719   score: 1756.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9739   score: 1227.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9759   score: 1416.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9779   score: 1636.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9799   score: 1285.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9819   score: 1585.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9839   score: 1118.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9859   score: 1775.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9879   score: 1060.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9899   score: 1076.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9919   score: 1314.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 9939   score: 1432.0   memory length: 2000   epsilon: 0.009998671593271896

# %% [markdown]
# ### Tracking Convergence

# %%
state_tracked_sample = [agent.states_tracked[i] for i in range(len(agent.states_tracked)) if agent.states_tracked[i] < 1000]

# %%
plt.figure(0, figsize=(16,7))
plt.title('Q_value for state [0,0,0]  action (0,2)')
xaxis = np.asarray(range(0, len(agent.states_tracked)))
plt.semilogy(xaxis,np.asarray(agent.states_tracked))
plt.show()

# %%
score_tracked_sample = [score_tracked[i] for i in range(len(score_tracked)) if (i % 4 == 0)]

# %%
plt.figure(0, figsize=(16,7))
plt.title('Rewards per episode')
xaxis = np.asarray(range(0, len(score_tracked_sample)))
plt.plot(xaxis,np.asarray(score_tracked_sample))
plt.show()

# %% [markdown]
# #### Epsilon-decay sample function

# %% [markdown]
# <div class="alert alert-block alert-info">
# Try building a similar epsilon-decay function for your model.
# </div>

# %%
epsilon = []
epsilonVal = 1.0
for i in range(0,10000):
    epsilon.append(epsilonVal)
    epsilonVal *= 0.999

# %%
plt.plot(epsilon)
plt.show()
